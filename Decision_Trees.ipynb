# %% [markdown]
# <a href="https://colab.research.google.com/github/shr968/marvel/blob/main/Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown

import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import gdown

file_id = "1rY0RP4Dh8s-szCfY8pV0Ha1iCTrVxbdW"
url = f"https://drive.google.com/uc?id={file_id}"
gdown.download(url, 'data.csv', quiet=False)

df = pd.read_csv("data.csv")

d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

features = ['Age', 'Experience', 'Rank', 'Nationality']
X = df[features]
y = df['Go']

dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

plt.figure(figsize=(12,8))
tree.plot_tree(dtree, feature_names=features, filled=True)
plt.show()
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1rY0RP4Dh8s-szCfY8pV0Ha1iCTrVxbdW
# To: /content/data.csv
# 100%|██████████| 218/218 [00:00<00:00, 570kB/s]
